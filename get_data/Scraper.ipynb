# %%
import pandas as pd
import numpy as pd
import time
import selenium
from selenium import webdriver
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %%
driver=webdriver.Chrome(r'\chrome.exe')
# Out:
# C:\Users\LAPTOP\AppData\Local\Temp\ipykernel_20044\3317032591.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'\chrome.exe')

# %%
url = "https://www.cardekho.com/"
driver.get(url)
time.sleep(2)

# %%
Used_cars=driver.find_element(By.XPATH,'//li[@data-slug="/usedCars"]/a').get_attribute('href')
driver.get(Used_cars)
time.sleep(2)

# %%
url = "https://www.cardekho.com/used-cars+in+ahmedabad"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm(range(0,200)):
    time.sleep(0.5)
    driver.execute_script("window.scrollBy(0,1000)","")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-350)")
# Out:
# 100%|██████████| 200/200 [05:09<00:00,  1.55s/it]

# %%
Car_url_ahmedabad = []
Car_url_ahmedabad_new=[]
car_url_ahmedabad = driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 gsc_col-sm-6 gsc_col-md-4 cardColumn"]')
for j in tqdm(range(len(car_url_ahmedabad))):
    Car_url_ahmedabad_new.append(car_url_ahmedabad[j].find_element(By.TAG_NAME,'a').get_attribute('href'))
time.sleep(2)
# Out:
# 100%|██████████| 1220/1220 [00:23<00:00, 51.43it/s]

# %%
print(Car_url_ahmedabad_new)
# Out:
# ['https://www.cardekho.com/used-car-details/used-Mahindra-Xuv500-W11-At-Bsiv-cars-Ahmedabad_ffc31118-22f0-4249-8638-72649e720188.htm', 'https://www.cardekho.com/buy-used-car-details/used-Maruti-Celerio-Vxi-cars-Ahmedabad_129b2f2b-719e-44de-a337-cb4ee0d1f4b0.htm', 'https://www.cardekho.com/buy-used-car-details/used-Maruti-Baleno-Zeta-Cvt-cars-Ahmedabad_c86b7843-56be-4f76-8908-a6c3afd0bfc4.htm', 'https://www.cardekho.com/buy-used-car-details/used-Maruti-Swift-Vxi-cars-Ahmedabad_5d4a3723-9f0b-4803-8b2b-63d6a384794a.htm', 'https://www.cardekho.com/used-car-details/used-Tata-New-Safari-Xza-Plus-(o)-6str-At-Bsvi-cars-Ahmedabad_b7f83b18-e3b1-47e1-8449-36cc3cf16661.htm', 'https://www.cardekho.com/buy-used-car-details/used-Maruti-S-presso-Vxi-Plus-2019-2022-cars-Ahmedabad_404faa82-4d99-4578-a30b-f2034f77f6da.htm', 'https://www.cardekho.com/buy-used-car-details/used-Maruti-Alto-K10-Vxi-cars-Ahmedabad_d968dc11-489f-4216-91c2-cfe40d54f785.htm', 'https://www.cardekho.com/buy-used-car-details/used
# ...

# %%
url = "https://www.cardekho.com/used-cars+in+bangalore"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm(range(0,300)):
    time.sleep(0.75)
    driver.execute_script("window.scrollBy(0,1000)","")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-350)")
# Out:
# 100%|██████████| 300/300 [09:06<00:00,  1.82s/it]

# %%
Car_url_bangalore = []
car_url_bangalore = driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 gsc_col-sm-6 gsc_col-md-4 cardColumn"]')
for j in tqdm(range(len(car_url_bangalore))):
    Car_url_bangalore.append(car_url_bangalore[j].find_element(By.TAG_NAME,'a').get_attribute('href'))
time.sleep(2)
# Out:
# 100%|██████████| 1700/1700 [00:18<00:00, 94.06it/s]

# %%
url = "https://www.cardekho.com/used-cars+in+chennai"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm(range(0,250)):
    time.sleep(0.5)
    driver.execute_script("window.scrollBy(0,1000)","")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-350)")
# Out:
# 100%|██████████| 250/250 [06:23<00:00,  1.54s/it]

# %%
Car_url_chennai = []
car_url_chennai = driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 gsc_col-sm-6 gsc_col-md-4 cardColumn"]')
for j in tqdm(range(len(car_url_chennai))):
    Car_url_chennai.append(car_url_chennai[j].find_element(By.TAG_NAME,'a').get_attribute('href'))
time.sleep(2)
# Out:
# 100%|██████████| 460/460 [00:04<00:00, 94.61it/s]

# %%
url = "https://www.cardekho.com/used-cars+in+delhi-ncr"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm(range(0,1100)):
    time.sleep(0.5)
    driver.execute_script("window.scrollBy(0,1500)","")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")
# Out:
# 100%|██████████| 1100/1100 [29:36<00:00,  1.62s/it]

# %%
Car_url_Rajasthan = []
car_url_Rajasthan = driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 gsc_col-sm-6 gsc_col-md-4 cardColumn"]')
for j in tqdm(range(len(car_url_Rajasthan))):
    Car_url_Rajasthan.append(car_url_Rajasthan[j].find_element(By.TAG_NAME,'a').get_attribute('href'))
time.sleep(2)
# Out:
# 100%|██████████| 1860/1860 [03:17<00:00,  9.44it/s]

# %%
url = "https://www.cardekho.com/used-cars+in+kerala"
driver.get(url)
time.sleep(2)

# %%
from tqdm import tqdm
for _ in tqdm(range(0,400)):
    time.sleep(0.5)
    driver.execute_script("window.scrollBy(0,1500)","")
    time.sleep(1)
    driver.execute_script("window.scrollBy(0,-500)")
# Out:
# 100%|██████████| 400/400 [10:14<00:00,  1.54s/it]

# %%
Car_url_Kerala = []
car_url_Kerala = driver.find_elements(By.XPATH,'//div[@class="gsc_col-xs-12 gsc_col-sm-6 gsc_col-md-4 cardColumn"]')
for j in tqdm(range(len(car_url_Kerala))):
    Car_url_Kerala.append(car_url_Kerala[j].find_element(By.TAG_NAME,'a').get_attribute('href'))
time.sleep(2)
# Out:
# 100%|██████████| 492/492 [00:05<00:00, 88.05it/s]

# %%
Car_url = Car_url_ahmedabad_new+Car_url_bangalore+Car_url_chennai+Car_url_Kerala+Car_url_Rajasthan

# %%
len(Car_url)
# Out:
# 5732
